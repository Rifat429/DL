# %% [markdown]
# <a href="https://colab.research.google.com/github/Rifat429/DL/blob/main/Data_augmentation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
img= image.load_img("/content/cat.jpg",target_size=(200,200))

# %%
import matplotlib.pyplot as plt
plt.imshow(img)

# %%
type(img)
# Out:
# PIL.Image.Image

# %%
datagen = ImageDataGenerator(rotation_range=30,
                             shear_range=0.2,
                             zoom_range=0.2,
                             width_shift_range=0.2,
                             height_shift_range=0.2,
                             horizontal_flip=True,
                             )
img= image.img_to_array(img)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
input_batch = img.reshape((1,)+img.shape)

# %%
input_batch.shape
# Out:
# (1, 200, 200, 3)

# %%
i= 0
for ouput in datagen.flow(input_batch,batch_size=1,save_to_dir='preview',save_prefix='cat',save_format='jpeg'):
  i+=1
  if i==10:
    break
