# %% [markdown]
# <a href="https://colab.research.google.com/github/Rifat429/DL/blob/main/Yolov8_crack_height_width_measuring.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Wed Sep 20 09:34:30 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
import os
HOME= os.getcwd()
print(HOME)
# Out:
# /content

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 618.0/618.0 kB 6.1 MB/s eta 0:00:00
# ...

# %%
from IPython import display
display.clear_output()
# !yolo mode=checks
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 393, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {MODES}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=<module 'ultralytics.utils.checks' from '/usr/local/lib/python3.10/dist-packages/ultralytics/utils/checks.py'>'. Valid modes are ('train', 'val', 'predict', 'export', 'track', 'benchmark').
#
#     Arguments received: ['yolo', 'mode=checks']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of ('detect', 'segment', 'classify', 'pose')
#                 MODE (required) is one of ('train', 'val', 'predict', 'export', 'track', 'benchmark')
#                 ARGS (optional) are any number of custom 'arg=value' pairs like 'imgsz=320' that override defaults.
# ...

# %%
from ultralytics import YOLO
from IPython.display import display, Image

# %%
 # %cd {HOME}
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='https://media.roboflow.com/notebooks/examples/dog.jpeg' save=True
# Out:
# /content
# ...
# 100% 6.23M/6.23M [00:00<00:00, 60.4MB/s]
# Ultralytics YOLOv8.0.182 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# ...
# 100% 104k/104k [00:00<00:00, 44.6MB/s]
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 102.5ms
# Speed: 9.5ms preprocess, 102.5ms inference, 17.2ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to runs/detect/predict
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
Image(filename='runs/detect/predict/dog.jpeg', height=600)
# Out:
# /content

# %%
model = YOLO(f'{HOME}/yolov8n.pt')
results = model.predict(source='https://media.roboflow.com/notebooks/examples/dog.jpeg', conf=0.25)
# Out:
# Found https://media.roboflow.com/notebooks/examples/dog.jpeg locally at dog.jpeg
# image 1/1 /content/dog.jpeg: 640x384 1 person, 1 car, 1 dog, 99.2ms
# Speed: 2.4ms preprocess, 99.2ms inference, 2.7ms postprocess per image at shape (1, 3, 640, 384)

# %%
results[0].boxes.xyxy
# Out:
# tensor([[   0.0000,  314.4717,  625.0754, 1278.1947],
#         [  55.1731,  250.0220,  648.1080, 1266.2720],
#         [ 633.2291,  719.5391,  701.0538,  786.0336]], device='cuda:0')

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="pNWm3q4Nw95IjkpDMdqc")
project = rf.workspace("csu-dv00b").project("road-crack-o7q1z")
dataset = project.version(1).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.7/58.7 kB 1.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 23.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 20.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 9.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.0.76
#     Uninstalling opencv-python-headless-4.8.0.76:
# ...

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml  epochs=50 imgsz=800 plots=True
# Out:
# /content
# Ultralytics YOLOv8.0.182 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# args.yaml  weights

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train3/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train3/val_batch0_pred.jpg', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train3/val_batch0_labels.jpg', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train3/results.png', width=600)
# Out:
# /content

# %%
# # model = YOLO(f'{HOME}/yolov8n.pt')
# model=YOLO("/content/yolov8s.pt")
# results = model(source='/content/Road-Crack-1/train/images/sample-6_jpg.rf.0397a00d72e3ed7920859f1cb4ae98f6.jpg', task="detect",conf=0.25)

# %%
# results

# %%
import cv2

# Load the image
image = cv2.imread('/content/runs/detect/train3/val_batch0_pred.jpg')

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply Gaussian blur
blurred = cv2.GaussianBlur(gray, (5, 5), 0)

# Thresholding
_, thresh = cv2.threshold(blurred, 100, 255, cv2.THRESH_BINARY)

# %%
contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# %%
for contour in contours:
    # Calculate length
    length = cv2.arcLength(contour, True)

    # Calculate width
    rect = cv2.minAreaRect(contour)
    width = rect[1][0] if rect[1][0] > rect[1][1] else rect[1][1]

    print(f"Crack Length: {length}, Crack Width: {width}")
# Out:
# Crack Length: 3324.0, Crack Width: 831.0

# %%
import cv2
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('/content/Road-Crack-1/train/images/sample-6_jpg.rf.0397a00d72e3ed7920859f1cb4ae98f6.jpg')

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply Gaussian blur
blurred = cv2.GaussianBlur(gray, (5, 5), 0)

# Thresholding
_, thresh = cv2.threshold(blurred, 100, 255, cv2.THRESH_BINARY)

# Find contours
contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Plot the original image
plt.figure(figsize=(12, 6))
plt.subplot(131)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title("Original Image")

# Plot the grayscale image
plt.subplot(132)
plt.imshow(gray, cmap='gray')
plt.title("Grayscale Image")

# Plot the thresholded image
plt.subplot(133)
plt.imshow(thresh, cmap='gray')
plt.title("Thresholded Image")

plt.tight_layout()
plt.show()

# Analyze contours and print results
for contour in contours:
    # Calculate length
    length = cv2.arcLength(contour, True)

    # Calculate width
    rect = cv2.minAreaRect(contour)
    width = rect[1][0] if rect[1][0] > rect[1][1] else rect[1][1]

    print(f"Crack Length: {length}, Crack Width: {width}")

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the image
image = cv2.imread('/content/Road-Crack-1/train/images/sample-6_jpg.rf.0397a00d72e3ed7920859f1cb4ae98f6.jpg')

# Convert to grayscale
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# Apply Gaussian blur
blurred = cv2.GaussianBlur(gray, (5, 5), 0)

# Thresholding
_, thresh = cv2.threshold(blurred, 100, 255, cv2.THRESH_BINARY)

# Find contours
contours, _ = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Plot the original image
plt.figure(figsize=(12, 6))
plt.subplot(131)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title("Original Image")

# Plot the grayscale image
plt.subplot(132)
plt.imshow(gray, cmap='gray')
plt.title("Grayscale Image")

# Plot the thresholded image
plt.subplot(133)
plt.imshow(thresh, cmap='gray')
plt.title("Thresholded Image")

plt.tight_layout()
plt.show()

# Initialize lists to store individual widths
individual_widths = []

# Analyze contours and print results
for contour in contours:
    # Calculate length
    length = cv2.arcLength(contour, True)

    # Calculate the average width
    rect = cv2.minAreaRect(contour)
    width = rect[1][0] if rect[1][0] > rect[1][1] else rect[1][1]

    # Append the width to the list
    individual_widths.append(width)

    print(f"Crack Length: {length}, Crack Width: {width}")

# Calculate the average width of all cracks
average_width = np.mean(individual_widths)
print(f"Average Crack Width for All Cracks: {average_width}")
# Out:
# Crack Length: 4.0, Crack Width: 1.0
# Crack Length: 3585.3595136404037, Crack Width: 639.0
# Average Crack Width for All Cracks: 320.0

# %%
# importing necessary libraries
import numpy as np
import cv2
from matplotlib import pyplot as plt

# read a cracked sample image
img = cv2.imread('/content/Road-Crack-1/train/images/sample-6_jpg.rf.0397a00d72e3ed7920859f1cb4ae98f6.jpg')

# Convert into gray scale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Image processing ( smoothing )
# Averaging
blur = cv2.blur(gray,(3,3))

# Apply logarithmic transform
img_log = (np.log(blur+1)/(np.log(1+np.max(blur))))*255

# Specify the data type
img_log = np.array(img_log,dtype=np.uint8)

# Image smoothing: bilateral filter
bilateral = cv2.bilateralFilter(img_log, 5, 75, 75)

# Canny Edge Detection
edges = cv2.Canny(bilateral,100,200)

# Morphological Closing Operator
kernel = np.ones((5,5),np.uint8)
closing = cv2.morphologyEx(edges, cv2.MORPH_CLOSE, kernel)

# Create feature detecting method
# sift = cv2.xfeatures2d.SIFT_create()
# surf = cv2.xfeatures2d.SURF_create()
orb = cv2.ORB_create(nfeatures=1500)

# Make featured Image
keypoints, descriptors = orb.detectAndCompute(closing, None)
featuredImg = cv2.drawKeypoints(closing, keypoints, None)

# # Create an output image
# cv2.imwrite('Output-Set/CrackDetected-7.jpg', featuredImg)

# Use plot to show original and output image
plt.subplot(121),plt.imshow(img)
plt.title('Original'),plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(featuredImg,cmap='gray')
plt.title('Output Image'),plt.xticks([]), plt.yticks([])
plt.show()

# %%
featuredImg=featuredImg.astype('uint8')
contours, _ = cv2.findContours(featuredImg, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-21-7bf403acb8b5> in <cell line: 2>()
#       1 featuredImg=featuredImg.astype('uint8')
# ----> 2 contours, _ = cv2.findContours(featuredImg, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#
# error: OpenCV(4.8.0) /io/opencv/modules/imgproc/src/contours.cpp:195: error: (-210:Unsupported format or combination of formats) [Start]FindContours supports only CV_8UC1 images when mode != CV_RETR_FLOODFILL otherwise supports CV_32SC1 images only in function 'cvStartFindContours_Impl'

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt
import imutils

# # Load the preprocessed image (featuredImg)
# featuredImg = cv2.imread('Output-Set/CrackDetected-7.jpg', cv2.IMREAD_GRAYSCALE)
gray = cv2.cvtColor(featuredImg, cv2.COLOR_BGR2GRAY)

# Extract contours from the featured image
contours, _ = cv2.findContours(featuredImg, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Sort the contours by their y-coordinate (top to bottom)
contours = sorted(contours, key=lambda x: cv2.boundingRect(x)[1])

# Initialize a variable to store crack information
crack_info = []

# Iterate through the sorted contours
for contour in contours:
    # Get the bounding rectangle of the contour
    x, y, w, h = cv2.boundingRect(contour)

    # Calculate the aspect ratio (width to height ratio)
    aspect_ratio = w / h

    # Append crack information to the list
    crack_info.append((x, y, w, h, aspect_ratio))

# Calculate the pixel ratio of the image (if you have a reference object measurement, use it here)
pixel_ratio = 1.0  # You can set this based on your reference object

# Iterate through the crack information and display the dimensions on the image
for i, (x, y, w, h, aspect_ratio) in enumerate(crack_info):
    # Calculate the actual width and height based on the pixel ratio
    actual_width = w * pixel_ratio
    actual_height = h * pixel_ratio

    # Draw the bounding rectangle on the image
    cv2.rectangle(featuredImg, (x, y), (x + w, y + h), (0, 255, 0), 2)

    # Display the dimensional information in the image
    info_text = f"Crack {i + 1}: Width={actual_width:.2f} mm, Height={actual_height:.2f} mm"
    cv2.putText(featuredImg, info_text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

# Show the processed image with dimensions
plt.imshow(cv2.cvtColor(featuredImg, cv2.COLOR_BGR2RGB))
plt.title('Processed Image with Dimensions')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-12-af53706d0387> in <cell line: 11>()
#       9
#      10 # Extract contours from the featured image
# ---> 11 contours, _ = cv2.findContours(featuredImg, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)
#      12
#      13 # Sort the contours by their y-coordinate (top to bottom)
#
# error: OpenCV(4.8.0) /io/opencv/modules/imgproc/src/contours.cpp:195: error: (-210:Unsupported format or combination of formats) [Start]FindContours supports only CV_8UC1 images when mode != CV_RETR_FLOODFILL otherwise supports CV_32SC1 images only in function 'cvStartFindContours_Impl'

# %%
# Sort the contours by their y-coordinate (top to bottom)
contours = sorted(contours, key=lambda x: cv2.boundingRect(x)[1])

# Initialize a variable to store crack information
crack_info = []

# Iterate through the sorted contours
for contour in contours:
    # Get the bounding rectangle of the contour
    x, y, w, h = cv2.boundingRect(contour)

    # Calculate the aspect ratio (width to height ratio)
    aspect_ratio = w / h

    # Append crack information to the list
    crack_info.append((x, y, w, h, aspect_ratio))

# Calculate the pixel ratio of the image (if you have a reference object measurement, use it here)
pixel_ratio = 1.0  # You can set this based on your reference object

# Iterate through the crack information and display the dimensions on the image
for i, (x, y, w, h, aspect_ratio) in enumerate(crack_info):
    # Calculate the actual width and height based on the pixel ratio
    actual_width = w * pixel_ratio
    actual_height = h * pixel_ratio

    # Draw the bounding rectangle on the image
    cv2.rectangle(img, (x, y), (x + w, y + h), (0, 255, 0), 2)

    # Display the dimensional information in the image
    info_text = f"Crack {i + 1}: Width={actual_width:.2f} mm, Height={actual_height:.2f} mm"
    cv2.putText(img, info_text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

# Show the processed image with dimensions
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.title('Processed Image with Dimensions')
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-4-a1446195701a> in <cell line: 43>()
#      70
#      71         # Draw the segment on the output image (optional)
# ---> 72         cv2.drawContours(output_img, [segment], -1, (0, 255, 0), 2)
#      73
#      74 # Show the original and output images
#
# error: OpenCV(4.8.0) /io/opencv/modules/imgproc/src/drawing.cpp:2634: error: (-215:Assertion failed) reader.ptr != NULL in function 'cvDrawContours'

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Read the cracked sample image
img = cv2.imread('/content/Road-Crack-1/train/images/sample-6_jpg.rf.0397a00d72e3ed7920859f1cb4ae98f6.jpg')

# Convert the image to grayscale (CV_8UC1 format)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Image processing (smoothing)
# Averaging
blur = cv2.blur(gray, (3, 3))

# Apply logarithmic transform
img_log = (np.log(blur + 1) / (np.log(1 + np.max(blur)))) * 255

# Specify the data type
img_log = np.array(img_log, dtype=np.uint8)

# Image smoothing: bilateral filter
bilateral = cv2.bilateralFilter(img_log, 5, 75, 75)

# Canny Edge Detection
edges = cv2.Canny(bilateral, 100, 200)

# Morphological Closing Operator
kernel = np.ones((5, 5), np.uint8)
closing = cv2.morphologyEx(edges, cv2.MORPH_CLOSE, kernel)

# Create feature detecting method
orb = cv2.ORB_create(nfeatures=1500)

# Detect keypoints and descriptors
keypoints, descriptors = orb.detectAndCompute(closing, None)

# Create a copy of the original image to draw results on
output_img = img.copy()

# Calculate the pixel ratio of the image (if you have a reference object measurement, use it here)
pixel_ratio = 1.0  # You can set this based on your reference object

# Initialize a list to store crack information
crack_info = []

# Find contours in the processed image (closing)
contours, _ = cv2.findContours(closing, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Sort the contours by their y-coordinate (top to bottom)
contours = sorted(contours, key=lambda x: cv2.boundingRect(x)[1])

# Iterate through the sorted contours
for i, contour in enumerate(contours):
    # Get the bounding rectangle of the contour
    x, y, w, h = cv2.boundingRect(contour)

    # Calculate the aspect ratio (width to height ratio)
    aspect_ratio = w / h

    # Calculate the actual width and height based on the pixel ratio
    actual_width = w * pixel_ratio
    actual_height = h * pixel_ratio

    # Draw the bounding rectangle on the output image
    cv2.rectangle(output_img, (x, y), (x + w, y + h), (0, 255, 0), 2)

    # Display the dimensional information in the image
    info_text = f"Crack {i + 1}: Width={actual_width:.2f} mm, Height={actual_height:.2f} mm"
    cv2.putText(output_img, info_text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)
    print(info_text)

# Show the processed image with dimensions
plt.imshow(cv2.cvtColor(output_img, cv2.COLOR_BGR2RGB))
plt.title('Processed Image with Dimensions')
plt.axis('off')
plt.show()
# Out:
# Crack 1: Width=10.00 mm, Height=9.00 mm
# Crack 2: Width=224.00 mm, Height=19.00 mm
# Crack 3: Width=106.00 mm, Height=20.00 mm
# Crack 4: Width=31.00 mm, Height=11.00 mm
# Crack 5: Width=15.00 mm, Height=6.00 mm
# Crack 6: Width=7.00 mm, Height=4.00 mm
# Crack 7: Width=152.00 mm, Height=46.00 mm

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# Read the cracked sample image
img = cv2.imread('/content/Road-Crack-1/train/images/sample-6_jpg.rf.0397a00d72e3ed7920859f1cb4ae98f6.jpg')

# Convert the image to grayscale (CV_8UC1 format)
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Image processing (smoothing)
# Averaging
blur = cv2.blur(gray, (3, 3))

# Apply logarithmic transform
img_log = (np.log(blur + 1) / (np.log(1 + np.max(blur)))) * 255

# Specify the data type
img_log = np.array(img_log, dtype=np.uint8)

# Image smoothing: bilateral filter
bilateral = cv2.bilateralFilter(img_log, 5, 75, 75)

# Increase the lower and upper threshold values for Canny edge detection
edges = cv2.Canny(bilateral, 50, 150)  # Adjust as needed

# Morphological Closing Operator (you can adjust the kernel size as well)
kernel = np.ones((5, 5), np.uint8)
closing = cv2.morphologyEx(edges, cv2.MORPH_CLOSE, kernel)

# Create feature detecting method
orb = cv2.ORB_create(nfeatures=1500)

# Detect keypoints and descriptors
keypoints, descriptors = orb.detectAndCompute(closing, None)

# Create a copy of the original image to draw results on
output_img = img.copy()

# Calculate the pixel ratio of the image (if you have a reference object measurement, use it here)
pixel_ratio = 1.0  # You can set this based on your reference object

# Initialize a list to store crack information
crack_info = []

# Find contours in the processed image (closing) with RETR_LIST mode
contours, _ = cv2.findContours(closing, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)

# Sort the contours by their y-coordinate (top to bottom)
contours = sorted(contours, key=lambda x: cv2.boundingRect(x)[1])

# Iterate through the sorted contours
for i, contour in enumerate(contours):
    # Get the bounding rectangle of the contour
    x, y, w, h = cv2.boundingRect(contour)

    # Calculate the aspect ratio (width to height ratio)
    aspect_ratio = w / h

    # Calculate the actual width and height based on the pixel ratio
    actual_width = w * pixel_ratio
    actual_height = h * pixel_ratio

    # Draw the bounding rectangle on the output image
    cv2.rectangle(output_img, (x, y), (x + w, y + h), (0, 255, 0), 2)

    # Display the dimensional information in the image
    info_text = f"Crack {i + 1}: Width={actual_width:.2f} mm, Height={actual_height:.2f} mm"
    cv2.putText(output_img, info_text, (x, y - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)

# Show the processed image with dimensions
plt.imshow(cv2.cvtColor(output_img, cv2.COLOR_BGR2RGB))
plt.title('Processed Image with Dimensions')
plt.axis('off')
plt.show()
